# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
import warnings 
warnings.filterwarnings("ignore")

# %%
path = "./test_image.jpg"
img = cv2.imread(path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
img = cv2.resize(img, (256,256))
X = np.reshape(img, (-1,3))

X = X.astype('float32')

# %%
from sklearn.cluster import KMeans 

kmeans = KMeans(n_clusters= 5, random_state= 14) 
kmeans.fit(X)

CLOSEST_PRIMARY_COLOR = kmeans.predict(X)
c = kmeans.cluster_centers_[CLOSEST_PRIMARY_COLOR]

c = c.reshape(img.shape)

plt.figure(figsize= (10,8))
plt.subplot(1,2,1)
plt.imshow(img)
plt.title("original image")
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(c.astype(int))
plt.title("Segmented image for k = 5")
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)
